# %%
import pandas as pd

# %%
parse_dates = ['lpep_pickup_datetime', 'lpep_dropoff_datetime']

# %%
df = pd.read_csv("./green_tripdata_2020-10.csv", sep=",", parse_dates = parse_dates, date_format='%Y/%m/%d %H:%M:%S')
# Out:
# /var/folders/p_/ld5fnvx11b7db63fgts97k540000gn/T/ipykernel_63832/664283026.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./green_tripdata_2020-10.csv", sep=",", parse_dates = parse_dates, date_format='%Y/%m/%d %H:%M:%S')

# %%
print(df.shape)
# Out:
# (95120, 20)

# %%
print(df.columns)
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0       2.0  2020-10-01 00:31:19   2020-10-01 00:34:55                  N
# 1       2.0  2020-10-01 00:42:12   2020-10-01 00:43:51                  N
# 2       2.0  2020-10-01 00:53:09   2020-10-01 00:55:39                  N
# 3       1.0  2020-10-01 00:12:29   2020-10-01 00:20:08                  N
# 4       1.0  2020-10-01 00:32:38   2020-10-01 00:43:02                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0             7             7              1.0           0.79
# 1         1.0           179             7              1.0           0.50
# 2         1.0           179           223              1.0           0.60
# 3         1.0           134           216              2.0           4.40
# 4         1.0            82             7              1.0           2.90
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
# url = f'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2020-{month}.csv.gz'

for i in range(10,13):
    print(f'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2020-{i}.csv.gz')
# Out:
# https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2020-10.csv.gz
# https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2020-11.csv.gz
# https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2020-12.csv.gz

# %%
for month in range(10,13):
        
    month_str = f"{month:02d}"
    print(month_str)
# Out:
# 10
# 11
# 12

# %%
df[df['passenger_count'] == 0]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 153         2.0  2020-10-01 07:32:29   2020-10-01 07:32:35                  N
# 483         1.0  2020-10-01 10:07:41   2020-10-01 10:31:50                  N
# 484         1.0  2020-10-01 10:35:21   2020-10-01 10:55:56                  N
# 581         1.0  2020-10-01 11:57:56   2020-10-01 12:25:20                  N
# 694         1.0  2020-10-01 12:48:04   2020-10-01 13:02:00                  N
# ...         ...                  ...                   ...                ...
# 51748       1.0  2020-10-31 15:18:04   2020-10-31 15:33:01                  N
# 51905       1.0  2020-10-31 16:32:02   2020-10-31 16:42:42                  N
# 52043       1.0  2020-10-31 17:21:39   2020-10-31 17:25:53                  N
# 52044       1.0  2020-10-31 17:47:03   2020-10-31 18:05:54                  N
# 52180       1.0  2020-10-31 18:24:44   2020-10-31 18:37:40                  N
#
# ...

# %%
df['VendorID'].unique()
# Out:
# array([ 2.,  1., nan])
